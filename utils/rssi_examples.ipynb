# %%
# %matplotlib inline

import numpy as np
import matplotlib
from pylab import *
import os
import pandas as pd

# %%
# %run -i rssi_representation.py
# Out:
# Training data:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 5     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  FLOOR  BUILDINGID  SPACEID  RELATIVEPOSITION  USERID  PHONEID  \
# 0     100  ...      2           1      106                 2       2       23
# 1     100  ...      2           1      106                 2       2       23
# 2     100  ...      2           1      103                 2       2       23
# 3     100  ...      2           1      102                 2       2       23
# 5     100  ...      2           1      105                 2       2       23
#
# ...

# %%
training_df.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 5     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  FLOOR  BUILDINGID  SPACEID  RELATIVEPOSITION  USERID  PHONEID  \
# 0     100  ...      2           1      106                 2       2       23
# 1     100  ...      2           1      106                 2       2       23
# 2     100  ...      2           1      103                 2       2       23
# 3     100  ...      2           1      102                 2       2       23
# 5     100  ...      2           1      105                 2       2       23
#
# ...

# %%
training_df.shape
# Out:
# (19861, 532)

# %%
#subplot(1, 2, 1)
plot(training_df.WAPs_RSSIs[0][:,0], label='WAP')
#subplot(1, 2, 2)
plot(training_df.WAPs_RSSIs[0][:,1], label='RSSI')
legend()

# %%
validation_df.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  FLOOR  BUILDINGID  SPACEID  RELATIVEPOSITION  USERID  PHONEID  \
# 0     100  ...      1           1        0                 0       0        0
# 1     100  ...      4           2        0                 0       0       13
# 2     100  ...      4           2        0                 0       0       13
# 3     100  ...      4           2        0                 0       0       13
# 4     100  ...      2           0        0                 0       0        2
#
# ...

# %%
validation_df.shape
# Out:
# (1111, 532)

# %%
#subplot(1, 2, 1)
plot(validation_df.WAPs_RSSIs[4][:,0], label='WAP')
#subplot(1, 2, 2)
plot(validation_df.WAPs_RSSIs[4][:,1], label='RSSI')
legend()
