# %%
import pandas as pd

# %%
train_df = pd.read_csv("./data/ujiindoorloc/trainingdata.csv")
test_df = pd.read_csv("./data/ujiindoorloc/validationdata.csv")

# %%
import itertools

# %%
train_df_classification_dict = {a: b for a, b in train_df.groupby("PHONEID")}

# %%
train_df_classification_dict[1]
# Out:
#       WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 4629     100     100     100     100     100     100     100     100     100
# 4633     100     100     100     100     100     100     100     100     100
# 4634     100     100     100     100     100     100     100     100     100
# 4635     100     100     100     100     100     100     100     100     100
# 4636     100     100     100     100     100     100     100     100     100
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 5134     100     100     100     100     100     100     100     100     100
# 5135     100     100     100     100     100     100     100     100     100
# 5137     100     100     100     100     100     100     100     100     100
# 5138     100     100     100     100     100     100     100     100     100
# 5139     100     100     100     100     100     100     100     100     100
#
#       WAP010  ...  WAP520    LONGITUDE      LATITUDE  FLOOR  BUILDINGID  \
# 4629     100  ...     100 -7536.584400  4.864918e+06      3           1
# 4633     100  ...     100 -7519.111800  4.864950e+06      3           1
# 4634     100  ...     100 -7513.104491  4.864944e+06      3           1
# 4635     100  ...     100 -7526.320097  4.864920e+06      3           1
# 4636     100  ...     100 -7524.351300  4.864934e+06      3           1
# ...      ...  ...     ...          ...           ...    ...         ...
# 5134     100  ...     100 -7310.764900  4.864808e+06      0           2
# 5135     100  ...     100 -7304.483600  4.864821e+06      0           2
# 5137     100  ...     100 -7316.835800  4.864814e+06      0           2
# 5138     100  ...     100 -7322.587600  4.864821e+06      0           2
# 5139     100  ...     100 -7322.620948  4.864813e+06      0           2
#
#       SPACEID  RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 4629      101                 2       8        1  1371714017
# 4633      102                 2       8        1  1371714444
# 4634      102                 1       8        1  1371714370
# 4635      101                 1       8        1  1371714217
# 4636      102                 2       8        1  1371714326
# ...       ...               ...     ...      ...         ...
# 5134      125                 2       8        1  1371720847
# 5135      122                 2       8        1  1371720916
# 5137      104                 2       8        1  1371721030
# 5138      103                 2       8        1  1371721150
# 5139      104                 1       8        1  1371721060
#
# [507 rows x 529 columns]

# %%
# 为每个切片按时间排序
for df in train_df_classification_dict.values():
    df.sort_values("TIMESTAMP", inplace=True)

# %%
train_df_classification_dict[1]
# Out:
#       WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 4680     100     100     100     100     100     100     100     100     100
# 4733     100     100     100     100     100     100     100     100     100
# 4786     100     100     100     100     100     100     100     100     100
# 4843     100     100     100     100     100     100     100     100     100
# 4892     100     100     100     100     100     100     100     100     100
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 4989     100     100     100     100     100     100     100     100     100
# 5043     100     100     100     100     100     100     100     100     100
# 5091     100     100     100     100     100     100     100     100     100
# 5138     100     100     100     100     100     100     100     100     100
# 4681     100     100     100     100     100     100     100     100     100
#
#       WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  \
# 4680     100  ...     100 -7536.5844  4.864918e+06      3           1
# 4733     100  ...     100 -7536.5844  4.864918e+06      3           1
# 4786     100  ...     100 -7536.5844  4.864918e+06      3           1
# 4843     100  ...     100 -7536.5844  4.864918e+06      3           1
# 4892     100  ...     100 -7536.5844  4.864918e+06      3           1
# ...      ...  ...     ...        ...           ...    ...         ...
# 4989     100  ...     100 -7322.5876  4.864821e+06      0           2
# 5043     100  ...     100 -7322.5876  4.864821e+06      0           2
# 5091     100  ...     100 -7322.5876  4.864821e+06      0           2
# 5138     100  ...     100 -7322.5876  4.864821e+06      0           2
# 4681     100  ...     100 -7322.5876  4.864821e+06      0           2
#
#       SPACEID  RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 4680      101                 2       8        1  1371714003
# 4733      101                 2       8        1  1371714005
# 4786      101                 2       8        1  1371714006
# 4843      101                 2       8        1  1371714008
# 4892      101                 2       8        1  1371714009
# ...       ...               ...     ...      ...         ...
# 4989      103                 2       8        1  1371721146
# 5043      103                 2       8        1  1371721147
# 5091      103                 2       8        1  1371721149
# 5138      103                 2       8        1  1371721150
# 4681      103                 2       8        1  1371721152
#
# [507 rows x 529 columns]

# %%
train_df_classification_dict[1]["TIMESTAMP"].plot()
# Out:
# <AxesSubplot:>

# %%
# class TimeStampFilter:
#     def __init__(self, df, step_max=200, key="TIMESTAMP"):
#         self.number = 0
#         self.df = df
#         self.step_max = step_max
#         self.key = key
#         self.last = None
#     def __call__(self, index):
#         value = self.df[self.key][index]
#         # print(self.key, index, "->", value)
#         if self.last is None:
#             self.last = value
#             return self.number
#         if abs(self.last - value) > self.step_max:
#             self.number += 1
#         self.last = value
#         return self.number

# %%
# train_df_classification_dict = {a: b for a, b in train_df.groupby("PHONEID")}
# # 为每个切片按时间排序
# for df in train_df_classification_dict.values():
#     df.sort_values("TIMESTAMP", inplace=True)
# # 将每个切片按时间戳跳跃再次切片
# values = train_df_classification_dict.values()
# train_df_classification_dict = {}
# for df in values:
#     tsf = TimeStampFilter(df, 40)
#     for _, df in df.groupby(tsf):
#         sb = set(df['BUILDINGID'])
#         sf = set(df['FLOOR'])
#         ss = set(df['SPACEID'])
#         assert len(sb) == 1
#         assert len(sf) == 1
#         assert len(ss) == 1
#         key = f"{sb.pop()}-{sf.pop()}-{ss.pop()}"
#         assert (key not in train_df_classification_dict)
#         train_df_classification_dict[key] = df

# %%
# train_df_classification_dict = {a: b for a, b in train_df.groupby("PHONEID")}
# # 为每个切片按时间排序
# for df in train_df_classification_dict.values():
#     df.sort_values("TIMESTAMP", inplace=True)
# # 将每个切片按时间戳跳跃再次切片
# train_df_classification_list = []
# df = train_df_classification_dict[1]  # 试试水
# tsf = TimeStampFilter(df, 1)
# for _, df in df.groupby(tsf):
#     train_df_classification_list.append(df)

# %%
 class PlaceIDFilter:
    def __init__(self, df, keys=["BUILDINGID", "FLOOR", "SPACEID"]):
        self.number = 0
        self.df = df
        self.keys = keys
    def __call__(self, index):
        values = []
        for col in self.keys:
            values.append(str(self.df[col][index]))
        return "-".join(values)

# %%
train_df_classification_dict = {a: b for a, b in train_df.groupby("PHONEID")}
# 为每个切片按时间排序
for df in train_df_classification_dict.values():
    df.sort_values("TIMESTAMP", inplace=True)
# 将每个切片按标签再次切片
items = train_df_classification_dict.items()
train_df_classification_dict = {}
for key, df in items:
    d = train_df_classification_dict[key] = {}
    pif = PlaceIDFilter(df)
    for key, df in df.groupby(pif):
        d.setdefault(key, []).append(df)

# %%
lengths = set()
for phone_values in train_df_classification_dict.values():
    for i in phone_values.values():
        lengths.add(len(i))

# %%
lengths
# Out:
# {1}

# %%
for phone_values in train_df_classification_dict.values():
    for k, v in phone_values.items():
        assert len(v) == 1
        phone_values[k] = v[0]

# %%
# cleared_train_data = pd.DataFrame(train_df_classification_dict)

# %%
# cleared_train_data.to_csv("./data/cleared_train_data.csv")

# %%
# ctd = pd.read_csv("./data/cleared_train_data.csv", index_col=0)

# %%
for phone_values in train_df_classification_dict.values():
    for df in phone_values.values():
        print(df.shape[0])
# Out:
# 33
# 30
# 20
# 31
# 10
# 10
# 10
# 10
# 10
# 20
# 20
# 10
# 10
# 20
# 10
# 10
# 10
# 10
# 10
# 20
# 10
# 20
# 10
# 10
# 10
# 20
# 10
# 24
# 18
# 10
# 18
# 23
# 10
# 10
# 10
# 10
# 10
# 10
# 20
# 10
# 10
# 10
# 17
# 10
# 10
# 14
# 21
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 20
# 20
# 27
# 10
# 10
# 10
# 9
# 10
# 8
# 10
# 10
# 10
# 10
# 10
# 10
# 22
# 9
# 7
# 10
# 10
# 10
# 31
# 10
# 10
# 20
# 1
# 4
# 1
# 8
# 11
# 10
# 10
# 30
# 70
# 20
# 10
# 30
# 30
# 20
# 20
# 20
# 20
# 20
# 10
# 20
# 30
# 10
# 10
# 30
# 10
# 10
# 50
# 50
# 20
# 10
# 20
# 20
# 20
# 30
# 10
# 20
# 20
# 10
# 10
# 20
# 10
# 10
# 10
# 10
# 10
# 30
# 10
# 20
# 20
# 13
# 23
# 20
# 24
# 10
# 20
# 20
# 10
# 10
# 11
# 9
# 10
# 10
# 10
# 10
# 20
# 20
# 20
# 10
# 20
# 20
# 10
# 20
# 10
# 20
# 30
# 20
# 23
# 10
# 20
# 10
# 30
# 10
# 8
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 28
# 20
# 20
# 20
# 20
# 40
# 52
# 29
# 20
# 30
# 20
# 10
# 10
# 10
# 18
# 10
# 10
# 10
# 29
# 10
# 10
# 10
# 10
# 10
# 26
# 10
# 19
# 10
# 10
# 20
# 19
# 37
# 9
# 10
# 10
# 10
# 10
# 18
# 19
# 19
# 10
# 10
# 10
# 10
# 18
# 10
# 19
# 26
# 9
# 10
# 20
# 25
# 20
# 10
# 10
# 10
# 10
# 10
# 10
# 19
# 29
# 20
# 20
# 19
# 10
# 10
# 19
# 10
# 19
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
#